# %%
from metaflow import Flow, get_metadata
from io import StringIO
import geopandas as gpd

# %%
print("Current metadata provider: %s" % get_metadata())
# Out:
# Current metadata provider: local@/home/mblack/r/metaflow-sandbox

# %% [markdown]
# # Get the last successful run

# %%
run = Flow('RasterFootprintFlow').latest_successful_run
print("Using run: %s" % str(run))
# Out:
# Using run: Run('RasterFootprintFlow/1637581337082940')

# %%
run.finished_at
# Out:
# datetime.datetime(2021, 11, 22, 11, 42, 26, 672000)

# %%
list(run.steps())
# Out:
# [Step('RasterFootprintFlow/1637581337082940/end'),
#  Step('RasterFootprintFlow/1637581337082940/process'),
#  Step('RasterFootprintFlow/1637581337082940/start')]

# %% [markdown]
# # Inspect the data

# %%
result = gpd.read_file(StringIO(run.data.footprint))

# %%
result.head()
# Out:
#                                             geometry
# 0  POLYGON ((-2.26671 55.58274, -2.26480 55.58273...

# %%
result.geometry.iloc[0]
